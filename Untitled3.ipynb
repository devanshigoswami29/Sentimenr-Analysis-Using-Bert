# %%
# !pip install transformers

# %%
pip install datasets
# Out:
# ...
#   Using cached datasets-2.18.0-py3-none-any.whl (510 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.6 MB/s eta 0:00:00
# ...

# %%
pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
from sklearn.metrics import accuracy_score, f1_score
import numpy as np

# %%
# prompt: read csv file

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Sentiment analysis/project 2024/Dataset-20231210T071705Z-001/Dataset/IMDB Dataset.csv')

# %%
df_train=pd.read_csv('/content/drive/MyDrive/Sentiment analysis/project 2024/Dataset-20231210T071705Z-001/Dataset/train.csv')
df_test=pd.read_csv('/content/drive/MyDrive/Sentiment analysis/project 2024/Dataset-20231210T071705Z-001/Dataset/test.csv')

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# %%
def preprocess_function(examples,batched):
   return tokenizer(examples["review"], truncation=True)

# %%
# Call the preprocess_function with the renamed dataframes
tokenized_train = preprocess_function(df_train, batched=True)
tokenized_test = preprocess_function(df_test, batched=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-e2a2d84b28cc> in <cell line: 2>()
#       1 # Call the preprocess_function with the renamed dataframes
# ----> 2 tokenized_train = preprocess_function(df_train, batched=True)
#       3 tokenized_test = preprocess_function(df_test, batched=True)
#
# <ipython-input-33-7dabb935a90c> in preprocess_function(examples, batched)
#       1 def preprocess_function(examples,batched):
# ----> 2    return tokenizer(examples["review"], truncation=True)
#
# ...
